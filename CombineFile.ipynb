# %%
import json

# %%
# Load the contents of the first JSON file
with open('/Users/pan/Desktop/combine/new_BackFace.json', 'r') as f1:
    data1 = json.load(f1)

# Load the contents of the second JSON file
with open('/Users/pan/Desktop/combine/new_Face.json', 'r') as f2:
    data2 = json.load(f2)

# %%
data = {}

data['images'] = data1['images'] + data2['images']
data['annotations'] = data1['annotations'] + data2['annotations']
data['categories'] = [
    {
        "supercategory": "animal",
        "id": 1,
        "name": "animal",
        "keypoints": [
            "L_Eye",
            "R_Eye",
            "L_EarBase",
            "R_EarBase",
            "Nose",
            "Throat",
            "TailBase",
            "Withers",
            "L_F_Elbow",
            "R_F_Elbow",
            "L_B_Elbow",
            "R_B_Elbow",
            "L_F_Knee",
            "R_F_Knee",
            "L_B_Knee",
            "R_B_Knee",
            "L_F_Paw",
            "R_F_Paw",
            "L_B_Paw",
            "R_B_Paw"
        ],
        "skeleton": [
            [
                1,
                2
            ],
            [
                1,
                3
            ],
            [
                2,
                4
            ],
            [
                1,
                5
            ],
            [
                2,
                5
            ],
            [
                5,
                6
            ],
            [
                6,
                8
            ],
            [
                7,
                8
            ],
            [
                6,
                9
            ],
            [
                9,
                13
            ],
            [
                13,
                17
            ],
            [
                6,
                10
            ],
            [
                10,
                14
            ],
            [
                14,
                18
            ],
            [
                7,
                11
            ],
            [
                11,
                15
            ],
            [
                15,
                19
            ],
            [
                7,
                12
            ],
            [
                12,
                16
            ],
            [
                16,
                20
            ]
        ]
    }
]

# %%
with open('combined_annotation.json', 'w') as f:
    json.dump(data, f)
